# %%
from rasterio.windows import Window

w = pop_raster.read(1, window=Window(0, 0, 512, 256))
plot_raster(w)
# Out:
# (<Figure size 2160x720 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fa2fe3caa10>)

# %%
w = pop_raster.read(1, window=Window(6000, 6000, 512, 256))
plot_raster(w)
# Out:
# (<Figure size 2160x720 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fa2d87fced0>)
